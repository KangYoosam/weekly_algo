# %%
cum_returns.tail()
# Out:
#                           5        10       30        60       90
# 2018-05-28 00:00:00  0.11542  0.06658  0.06503  0.068065  0.09145
# 2018-05-29 00:00:00  0.11543  0.06659  0.06504  0.068075  0.09146
# 2018-05-30 00:00:00  0.11415  0.06531  0.06376  0.066795  0.09018
# 2018-05-31 00:00:00  0.11837  0.06953  0.06798  0.071015   0.0944
# 2018-06-01 00:00:00   0.1171  0.06826  0.06671  0.069745  0.09313

# %%
# %matplotlib inline
cum_returns.plot(figsize=(12, 4), rot=90)

# %%
summaries = pd.DataFrame([x.summary() for x in results], index=windows)
summaries['Beta'] = summaries['Beta'].map(lambda x: x[0])

# %%
summaries
# Out:
#         2015      2016      2017      2018     Alpha      Beta  MaxDrawdown  \
# 5   0.051415  0.009996  0.034781  0.016599  0.030653  0.031376    -0.016541
# 10  0.033315 -0.010732  0.038353  0.006435  0.017512  0.027618    -0.029602
# 30  0.027710 -0.019938  0.030301  0.027916  0.016716  0.031605    -0.046665
# 60 -0.007005  0.005569  0.040750  0.029378  0.017451  0.033226    -0.047857
# 90  0.010725 -0.002028  0.053461  0.028731  0.023308  0.040271    -0.031506
#
#    ReturnRatio  ReturnValue  SharpeRatio  SignalCount  TradingDays  Volatility
# 5         11.7     11171000     1.553061          170          837    0.021645
# 10        6.83     10682600     0.969632          104          837    0.020750
# 30        6.67     10667100     0.911561           65          837    0.021612
# 60        6.97     10697450     0.892376           45          837    0.023072
# 90        9.31     10931300     1.167961           42          837    0.023213

# %%
summaries.loc[:, '2015':'2018'].plot.bar()

# %%
summaries[['Alpha', 'Beta', 'MaxDrawdown']].plot.bar()

# %%
summaries['SharpeRatio'].plot.bar()
